# %% [markdown]
# # BORG EV Motor - Remanufacturing Inventory Simulation
#
# This notebook models a closed-loop remanufacturing inventory system for EV motors with:
#
# 1. customer demand each week
# 2. stochastic core returns from fulfilled demand
# 3. stochastic remanufacturing yield after a reman lead time
# 4. stochastic supplier lead times for new units
# 5. a simulation-based reorder policy evaluated with Monte Carlo runs
#
# The notebook now uses a **simulation-based** supplier policy:
#
# - the reorder point is treated as a policy input to test,
# - supplier orders are triggered from the simulated state,
# - order quantity is based on the simulated **inventory position**,
# - remanufacturing work-in-process is **not** converted into deterministic expected arrivals inside the policy.

# %%
import simpy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches
from dataclasses import dataclass, field
from typing import List, Tuple

plt.rcParams.update({'figure.dpi': 130, 'font.size': 10})
print('Libraries loaded.')
# Out:
# Libraries loaded.

# %% [markdown]
# ## Parameters

# %%
@dataclass
class Params:
    # Inventory limits
    max_stock:          int   = 60     # order-up-to level for supplier replenishment
    initial_stock:      int   = 60     # stock at simulation start

    # Demand
    demand_per_week:    int   = 25     # constant customer demand (units/week)

    # Closed-loop rates
    return_rate:        float = 0.87   # fraction of customers who return old cores
    reman_success_rate: float = 0.90   # fraction of returned cores successfully reman'd
    reman_lead_time:    float = 2.0    # weeks to complete remanufacturing

    # Supplier replenishment policy
    reorder_point:      int   = 35     # trigger supplier review when inventory position <= this value
    lt_mean:            float = 2.0    # supplier lead time mean (weeks)
    lt_std:             float = 0.5    # supplier lead time std dev (weeks)
    review_period:      float = 1.0    # review inventory once per week

    # Simulation
    sim_weeks:          int   = 104    # 2 years

# %%
p = Params()

# Descriptive averages shown for context only.
# These values help interpret the system but are not embedded in the supplier decision rule.
net_return_per_week = p.demand_per_week * p.return_rate * p.reman_success_rate
net_supplier_need_per_week = p.demand_per_week - net_return_per_week

print('Baseline settings')
print(f'  Max stock (order-up-to)    : {p.max_stock} units')
print(f'  Initial stock              : {p.initial_stock} units')
print(f'  Reorder point              : {p.reorder_point} units')
print(f'  Demand per week            : {p.demand_per_week} units')
print(f'  Avg reman returned/week    : {net_return_per_week:.2f} units')
print(f'  Avg external need/week     : {net_supplier_need_per_week:.2f} units')
print()
print('Policy interpretation')
print('  Review the system every week.')
print('  If simulated inventory position <= reorder point, place a supplier order.')
print('  Supplier order quantity = max_stock - inventory_position.')
print('  Inventory position uses current stock plus supplier units already on order.')
print('  Reman WIP is not converted into deterministic expected arrivals in the policy.')
# Out:
# Net return/week          : 19.57 units
# Net outflow/week         : 5.43 units
# Analytical ROP (95% SL)  : 15.3  →  set reorder_point = 15.312062500000003
# Order qty when triggered : max_stock − stock_at_trigger = 60 − 15.312062500000003 = 44.6879375

# %% [markdown]
# ## SimPy Simulation

# %%
class BORGSystem:
    """
    Closed-loop remanufacturing inventory system with a simulation-based
    order-up-to supplier policy.

    Processes
    ---------
    weekly_demand   : ships demand, records stockouts, launches reman jobs
    reman_process   : converts returned cores into good units after reman lead time
    reorder_monitor : reviews simulated inventory position once per week
    supplier_order  : supplier delivery arrives after a random lead time
    """

    def __init__(self, env: simpy.Environment, params: Params, rng: np.random.Generator):
        self.env = env
        self.p = params
        self.rng = rng
        self.stock = params.initial_stock
        self.supplier_units_on_order = 0

        # Log lists
        self.log_time: List[float] = []
        self.log_stock: List[int] = []
        self.log_inventory_position: List[int] = []
        self.log_demand: List[Tuple] = []            # (week, qty)
        self.log_stockouts: List[Tuple] = []         # (week, units_short)
        self.log_reman_in: List[Tuple] = []          # (week, units_added)
        self.log_orders: List[Tuple] = []            # (week_placed, qty, week_arrived)
        self.log_supplier_in: List[Tuple] = []       # (week, units_added)

        self._snap()

        env.process(self.weekly_demand())
        env.process(self.reorder_monitor())

    def inventory_position(self) -> int:
        # Simulation-based inventory position: what is on hand plus what is already
        # committed from the supplier. Reman WIP is excluded because yield is uncertain
        # until the reman process finishes.
        return int(self.stock + self.supplier_units_on_order)

    def _snap(self):
        self.log_time.append(self.env.now)
        self.log_stock.append(self.stock)
        self.log_inventory_position.append(self.inventory_position())

    def _add_to_stock(self, qty: int):
        self.stock += qty
        return qty

    def weekly_demand(self):
        while True:
            yield self.env.timeout(1)
            week = self.env.now

            demand = self.p.demand_per_week
            fulfilled = min(demand, self.stock)
            short = demand - fulfilled

            self.stock -= fulfilled
            self.log_demand.append((week, demand))

            if short > 0:
                self.log_stockouts.append((week, short))

            self._snap()

            cores_back = int(self.rng.binomial(fulfilled, self.p.return_rate))
            if cores_back > 0:
                self.env.process(self.reman_process(cores_back))

    def reman_process(self, n_cores: int):
        yield self.env.timeout(self.p.reman_lead_time)

        good_units = int(self.rng.binomial(n_cores, self.p.reman_success_rate))
        added = self._add_to_stock(good_units)

        self.log_reman_in.append((self.env.now, added))
        self._snap()

    def reorder_monitor(self):
        while True:
            yield self.env.timeout(self.p.review_period)

            inv_pos = self.inventory_position()
            if inv_pos <= self.p.reorder_point:
                order_qty = max(0, int(self.p.max_stock - inv_pos))
                if order_qty == 0:
                    continue

                self.supplier_units_on_order += order_qty
                record = [self.env.now, order_qty, None]
                self.log_orders.append(record)
                self.env.process(self.supplier_order(order_qty, record))
                self._snap()

    def supplier_order(self, qty: int, record: list):
        lead_time = max(0.1, float(self.rng.normal(self.p.lt_mean, self.p.lt_std)))
        yield self.env.timeout(lead_time)

        self.supplier_units_on_order -= qty
        self._add_to_stock(qty)
        record[2] = self.env.now
        self.log_supplier_in.append((self.env.now, qty))
        self._snap()


def run(params: Params = None, seed: int = 42) -> BORGSystem:
    if params is None:
        params = Params()
    rng = np.random.default_rng(seed)
    env = simpy.Environment()
    system = BORGSystem(env, params, rng)
    env.run(until=params.sim_weeks)
    return system


print('Simulation class defined.')
print()
print('Simulation-based supplier policy')
print(f'  Review period              : {p.review_period} week')
print(f'  Reorder point              : {p.reorder_point} units')
print(f'  Order-up-to level          : {p.max_stock} units')
print('  Inventory position         : stock + supplier units already on order')
print('  Reman WIP                  : excluded from ordering because yield is uncertain')
print('  Supplier order quantity    : max_stock - inventory_position when triggered')
# Out:
# Simulation class defined.
#
# ── Option A: smart order qty ───────────────────────────────────────
#   Stock at ROP trigger      : 35 units
#   Fill-to-max (naive)       : 25 units  ← would overshoot
#   Expected reman during LT  : 39.1 units  (subtracted)
#   Adjusted order qty        : 0 units  ← actual order placed
#   Expected stock at arrival : ~74 units

# %% [markdown]
# ## Single Run — Inventory Trajectory

# %%
sys = run(p, seed=42)

# KPIs
filled_demand     = sum(d[1] for d in sys.log_demand) - sum(s[1] for s in sys.log_stockouts)
total_demand      = sum(d[1] for d in sys.log_demand)
total_stockouts   = sum(s[1] for s in sys.log_stockouts)
service_level     = filled_demand / total_demand if total_demand else 1.0
n_orders          = len(sys.log_orders)
total_reman_in    = sum(r[1] for r in sys.log_reman_in)
total_supplier_in = sum(r[1] for r in sys.log_supplier_in)
avg_stock         = float(np.mean(sys.log_stock))
avg_inv_pos       = float(np.mean(sys.log_inventory_position))
avg_order_qty     = float(np.mean([o[1] for o in sys.log_orders])) if sys.log_orders else 0.0

print('?' * 56)
print(f'  Simulation weeks          : {p.sim_weeks}')
print(f'  Total demand              : {total_demand} units')
print(f'  Filled demand             : {filled_demand} units')
print(f'  Total stockouts           : {total_stockouts} units  ({len(sys.log_stockouts)} events)')
print(f'  Service level             : {service_level:.1%}')
print(f'  Reman units restocked     : {total_reman_in}')
print(f'  Supplier units delivered  : {total_supplier_in}')
print(f'  Supplier orders placed    : {n_orders}')
print(f'  Avg order quantity        : {avg_order_qty:.1f} units')
print(f'  Avg stock on hand         : {avg_stock:.1f} units')
print(f'  Avg inventory position    : {avg_inv_pos:.1f} units')
print('?' * 56)
# Out:
# ────────────────────────────────────────────────
#   Simulation weeks      : 104
#   Total demand          : 2575 units
#   Total stockouts       : 125 units  (34 events)
#   Service level         : 95.1%
#   Reman units restocked : 1894
#   Supplier orders       : 39
#   Avg inventory level   : 16.0 units
# ────────────────────────────────────────────────

# %%
fig, axes = plt.subplots(3, 1, figsize=(14, 10),
                         gridspec_kw={'height_ratios': [4, 1.5, 1.5]},
                         sharex=True)
fig.suptitle('BORG EV Motor Remanufacturing - Simulation-Based Inventory Policy\n'
             f'Demand = {p.demand_per_week} units/wk  |  ROP = {p.reorder_point}  |  '
             f'Order-up-to = {p.max_stock}',
             fontsize=11, fontweight='bold')

# Panel 1: stock level and inventory position
ax = axes[0]
ax.step(sys.log_time, sys.log_stock, where='post', lw=1.4,
        color='#1976D2', label='Stock on hand')
ax.step(sys.log_time, sys.log_inventory_position, where='post', lw=1.2,
        color='#6A1B9A', linestyle='--', label='Inventory position')
ax.fill_between(sys.log_time, sys.log_stock,
                step='post', alpha=0.12, color='#1976D2')
ax.axhline(p.reorder_point, color='#F57C00', lw=1.4, ls='--',
           label=f'Reorder point = {p.reorder_point}')
ax.axhline(p.max_stock, color='#388E3C', lw=1.0, ls='-.',
           label=f'Order-up-to = {p.max_stock}')

for placed, qty, arrived in sys.log_orders:
    if arrived is not None:
        ax.axvline(arrived, color='#388E3C', lw=0.7, alpha=0.4)
        ax.annotate(f'+{qty}', xy=(arrived, p.max_stock * 0.93),
                    fontsize=7, color='#388E3C', ha='center')

for week, short in sys.log_stockouts:
    ax.axvspan(week - 1, week, color='#EF9A9A', alpha=0.35)

red_patch = mpatches.Patch(color='#EF9A9A', alpha=0.5, label='Stockout event')
green_line = mpatches.Patch(color='#388E3C', alpha=0.5, label='Supplier delivery')
ax.legend(handles=ax.get_legend_handles_labels()[0] + [red_patch, green_line],
          fontsize=8, loc='upper right', ncol=3)
ax.set_ylabel('Units')
ax.set_ylim(0, p.max_stock + 15)
ax.set_title('Inventory State', fontsize=10)

# Panel 2: inflows from reman and supplier
ax2 = axes[1]
if sys.log_reman_in:
    reman_weeks, reman_qty = zip(*sys.log_reman_in)
    ax2.bar(reman_weeks, reman_qty, width=0.55, color='#66BB6A',
            alpha=0.8, label='Reman units added')
if sys.log_supplier_in:
    supplier_weeks, supplier_qty = zip(*sys.log_supplier_in)
    ax2.bar(supplier_weeks, supplier_qty, width=0.35, color='#FFA726',
            alpha=0.8, label='Supplier units added')
ax2.set_ylabel('Units')
ax2.set_title('Restocking Events', fontsize=10)
ax2.legend(fontsize=8)

# Panel 3: cumulative demand vs realized replenishment
ax3 = axes[2]
demand_weeks = [d[0] for d in sys.log_demand]
cum_demand = np.cumsum([d[1] for d in sys.log_demand])
reman_series = pd.Series(0, index=range(1, p.sim_weeks + 1))
supplier_series = pd.Series(0, index=range(1, p.sim_weeks + 1))
for wk, qty in sys.log_reman_in:
    wk_int = int(wk)
    if wk_int in reman_series.index:
        reman_series[wk_int] += qty
for wk, qty in sys.log_supplier_in:
    wk_int = int(wk)
    if wk_int in supplier_series.index:
        supplier_series[wk_int] += qty
cum_reman = reman_series.cumsum()
cum_supplier = supplier_series.cumsum()

ax3.plot(demand_weeks, cum_demand, color='#1976D2', lw=1.5, label='Cum. demand')
ax3.plot(cum_reman.index, cum_reman.values, color='#66BB6A',
         lw=1.5, ls='--', label='Cum. reman inflow')
ax3.plot(cum_supplier.index, cum_supplier.values, color='#FFA726',
         lw=1.5, ls='-.', label='Cum. supplier inflow')
ax3.set_xlabel('Week')
ax3.set_ylabel('Cumulative units')
ax3.set_title('Demand and Realized Supply Flows', fontsize=10)
ax3.legend(fontsize=8)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('borg_inventory_run.png', bbox_inches='tight')
plt.show()
print('Plot saved: borg_inventory_run.png')
# Out:
# Plot saved: borg_inventory_run.png

# %% [markdown]
# ## Reorder Point (ROP) Sensitivity Analysis
#
# This section uses Monte Carlo simulation to study how the **reorder point** affects service and inventory under the simulation-based supplier policy.
#
# Policy being tested:
# - review the system every week,
# - if simulated inventory position is at or below ROP, order up to `max_stock`,
# - inventory position includes stock on hand and supplier units already on order,
# - reman work-in-process is left stochastic and is not converted into an expected-value correction.

# %%
rop_values = list(range(20, 65, 5))
N_SEEDS = 20

results = []
for rop in rop_values:
    metrics = []
    for seed in range(N_SEEDS):
        params_run = Params(reorder_point=rop)
        s = run(params_run, seed=seed)

        total_demand = sum(d[1] for d in s.log_demand)
        total_stockouts = sum(x[1] for x in s.log_stockouts)
        filled = total_demand - total_stockouts
        service_level = filled / total_demand if total_demand else 1.0
        avg_inv = float(np.mean(s.log_stock))
        avg_inv_pos = float(np.mean(s.log_inventory_position))
        n_orders = len(s.log_orders)
        avg_order_qty = float(np.mean([o[1] for o in s.log_orders])) if s.log_orders else 0.0
        metrics.append((service_level, avg_inv, avg_inv_pos, n_orders, total_stockouts, avg_order_qty))

    arr = np.array(metrics)
    results.append({
        'rop': rop,
        'svc_mean': arr[:, 0].mean(),
        'svc_std': arr[:, 0].std(),
        'avg_inv_mean': arr[:, 1].mean(),
        'avg_inv_std': arr[:, 1].std(),
        'avg_inv_pos_mean': arr[:, 2].mean(),
        'orders_mean': arr[:, 3].mean(),
        'stockout_mean': arr[:, 4].mean(),
        'avg_order_qty_mean': arr[:, 5].mean(),
    })

df = pd.DataFrame(results)

display_cols = ['rop', 'svc_mean', 'avg_inv_mean', 'avg_inv_pos_mean',
                'orders_mean', 'avg_order_qty_mean', 'stockout_mean']
print(df[display_cols].to_string(
    index=False,
    formatters={
        'svc_mean': '{:.2%}'.format,
        'avg_inv_mean': '{:.1f}'.format,
        'avg_inv_pos_mean': '{:.1f}'.format,
        'orders_mean': '{:.1f}'.format,
        'avg_order_qty_mean': '{:.1f}'.format,
        'stockout_mean': '{:.1f}'.format,
    }
))
# Out:
#  rop  order_qty_when_triggered svc_mean avg_inv_mean orders_mean stockout_mean
#   20                        40   93.66%         16.0        40.0         163.3
#   25                        35   93.66%         16.0        40.0         163.3
#   30                        30   93.66%         16.0        40.0         163.3
#   35                        25   93.66%         16.0        40.0         163.3
#   40                        20   93.66%         16.0        40.0         163.3
#   45                        15   93.66%         16.0        40.0         163.3
#   50                        10   93.66%         16.0        40.0         163.3
#   55                         5   93.66%         16.0        40.0         163.3
#   60                         0   93.66%         16.0        40.0         163.3

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))
fig.suptitle('Reorder Point Sensitivity (20 Monte Carlo runs each)',
             fontsize=12, fontweight='bold')

color_main = '#1976D2'
color_band = '#BBDEFB'

# Service level
ax = axes[0]
svc = df['svc_mean'] * 100
svc_s = df['svc_std'] * 100
ax.plot(df['rop'], svc, 'o-', color=color_main, lw=2)
ax.fill_between(df['rop'], svc - svc_s, svc + svc_s,
                alpha=0.25, color=color_band)
ax.axvline(p.reorder_point, color='#F57C00', ls=':', lw=1.2,
           label=f'Baseline ROP={p.reorder_point}')
ax.set_xlabel('Reorder Point (units)')
ax.set_ylabel('Service Level (%)')
ax.set_title('Service Level vs ROP')
ax.set_ylim(85, 101)
ax.legend(fontsize=8)
ax.grid(alpha=0.3)

# Average inventory
ax2 = axes[1]
inv = df['avg_inv_mean']
inv_s = df['avg_inv_std']
ax2.plot(df['rop'], inv, 's-', color='#388E3C', lw=2, label='On-hand inventory')
ax2.plot(df['rop'], df['avg_inv_pos_mean'], 'd--', color='#6A1B9A', lw=1.6,
         label='Inventory position')
ax2.fill_between(df['rop'], inv - inv_s, inv + inv_s,
                 alpha=0.25, color='#C8E6C9')
ax2.axvline(p.reorder_point, color='#F57C00', ls=':', lw=1.2)
ax2.set_xlabel('Reorder Point (units)')
ax2.set_ylabel('Average Units')
ax2.set_title('Average Inventory vs ROP')
ax2.legend(fontsize=8)
ax2.grid(alpha=0.3)

# Supplier behavior
ax3 = axes[2]
ax3.bar(df['rop'], df['orders_mean'], width=3, color='#7B1FA2', alpha=0.75,
        label='Avg supplier orders')
ax3b = ax3.twinx()
ax3b.plot(df['rop'], df['avg_order_qty_mean'], 'D--',
          color='#F57C00', lw=1.5, label='Avg order qty')
ax3.set_xlabel('Reorder Point (units)')
ax3.set_ylabel('# Supplier Orders / 2 yr', color='#7B1FA2')
ax3b.set_ylabel('Average Order Qty (units)', color='#F57C00')
ax3.set_title('Supplier Ordering vs ROP')
lines1, labels1 = ax3.get_legend_handles_labels()
lines2, labels2 = ax3b.get_legend_handles_labels()
ax3.legend(lines1 + lines2, labels1 + labels2, fontsize=8)
ax3.grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('borg_rop_sensitivity.png', bbox_inches='tight')
plt.show()
print('Plot saved: borg_rop_sensitivity.png')
# Out:
# Plot saved: borg_rop_sensitivity.png

# %% [markdown]
# ## Order Timing and Quantity Decision Guide
#
# ### Simulation-Based Policy
#
# This notebook now uses a simulation-based replenishment rule rather than embedding deterministic expected reman returns inside the supplier decision.
#
# At each weekly review:
#
# $$
# \text{Inventory Position} = \text{Stock On Hand} + \text{Supplier Units Already On Order}
# $$
#
# If inventory position is at or below the reorder point,
#
# $$
# \text{Order Quantity} = \max(0, \text{MaxStock} - \text{Inventory Position})
# $$
#
# ### Why this is simulation-based
#
# - supplier lead time is random,
# - customer core returns are random,
# - remanufacturing yield is random,
# - reman units are only added when the simulated reman process actually finishes,
# - the supplier rule reacts to the simulated state instead of subtracting an expected reman quantity.
#
# ### Interpretation
#
# - `reorder_point` controls **when** the external supplier is used,
# - `max_stock` controls **how aggressively** the system refills once triggered,
# - Monte Carlo sensitivity analysis is used to compare service level, average inventory, and supplier dependence across different reorder points.
#
# This keeps the analytical role descriptive and the operational decision rule fully inside the simulation.

# %%
# ── Stock flow balance (sanity check) ───────────────────────────────────────
total_demand_all  = sum(d[1] for d in sys.log_demand)
total_reman_in_all = sum(r[1] for r in sys.log_reman_in)
total_supplier = sum(o[1] for o in sys.log_orders if o[2] is not None)
net_stock_change  = sys.log_stock[-1] - sys.log_stock[0]

print('── Stock Flow Balance ──────────────────────────────')
print(f'  Inflow : reman returns        = {total_reman_in_all:6d} units')
print(f'  Inflow : supplier deliveries  = {total_supplier:6d} units')
print(f'  Outflow: customer demand      = {total_demand_all:6d} units')
print(f'  Net stock change              = {net_stock_change:+6d} units')
print(f'  Check  (in - out - Δstock)   = {total_reman_in_all + total_supplier - total_demand_all - net_stock_change:+6d} (should be 0)')
print('────────────────────────────────────────────────────')
print(f'  Reman self-sufficiency        = {total_reman_in_all/total_demand_all:.1%}')
print(f'  External order dependency     = {total_supplier/total_demand_all:.1%}')
# Out:
# ── Stock Flow Balance ──────────────────────────────
#   Inflow : reman returns        =   1612 units
#   Inflow : supplier deliveries  =    402 units
#   Outflow: customer demand      =   2060 units
#   Net stock change              =    -46 units
#   Check  (in - out - Δstock)   =     +0 (should be 0)
# ────────────────────────────────────────────────────
#   Reman self-sufficiency        = 78.3%
#   External order dependency     = 19.5%
